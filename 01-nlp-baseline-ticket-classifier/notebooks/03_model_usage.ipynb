# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from src.inference import predict_ticket

test_examples = [
            # English
            ["Hello, I cannot access my corporate account, my login is blocked. Can someone reset my password?", "en"],
            ["I received an invoice with an incorrect amount. I was charged twice for the monthly subscription.", "en"],
            # German
            ["Guten Tag, der Server ist seit zwei Stunden down. Wir können nicht arbeiten.", "de"],
            ["Guten Morgen, ich habe ein Problem mit meinen Rechnungen, mir wurde der doppelte Betrag berechnet.", "de"],
            # Spanish
            ["Hola, quiero saber cómo puedo devolver este producto y obtener un reembolso.", "es"],
            # French
            ["Je souhaite postuler pour le poste de développeur Python, voici ma candidature.", "fr"],
            # Polish
            ["Dzień dobry, mam problem z fakturami, zostałem obciążony podwójnie kwotą.", "pl"],
            # General
            ["Just a quick question about your opening hours during weekends.", "en"]
        ]

for text, language in test_examples:
    predicted_category = predict_ticket(text, language)
    print(f"Text: {text}\nPredicted Category: {predicted_category}\n{'-'*50}")
# Out:
# 2026-05-22 21:55:52,504 - WARNING - Language 'pl' is not supported. Use one of: ['en', 'de', 'es', 'fr', 'pt']
# Text: Hello, I cannot access my corporate account, my login is blocked. Can someone reset my password?
# Predicted Category: Technical Support
# --------------------------------------------------
# Text: I received an invoice with an incorrect amount. I was charged twice for the monthly subscription.
# Predicted Category: Billing and Payments
# --------------------------------------------------
# Text: Guten Tag, der Server ist seit zwei Stunden down. Wir können nicht arbeiten.
# Predicted Category: Technical Support
# --------------------------------------------------
# Text: Guten Morgen, ich habe ein Problem mit meinen Rechnungen, mir wurde der doppelte Betrag berechnet.
# Predicted Category: Billing and Payments
# --------------------------------------------------
# Text: Hola, quiero saber cómo puedo devolver este producto y obtener un reembolso.
# ...
